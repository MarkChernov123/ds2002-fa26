# %% [markdown]
# <a href="https://colab.research.google.com/github/MarkChernov123/ds2002-fa26/blob/main/notebooks/01-foundations/2026-09-04%20%E2%80%94%20Submission%20Drill%20and%20Fix%20a%20Broken%20Notebook%20%E2%80%94%20Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DS2002 · Submission Drill and Fix a Broken Notebook
#
# **Lab — 2026-09-04 · Fall 2026**
#
# ---

# %% [markdown]
# ## Lab 02 — Submission Drill and Fix a Broken Notebook
#
# You have inherited a notebook that does not run. This is the most common way you will meet other people's code, so it is worth practicing deliberately.
#
# Seven cells below are broken. Five throw an error, and two return a wrong answer without complaining at all — those are the dangerous ones. Fix all seven, prove your fixes with assertions, then push through the full submit loop.
#
# **Submit in Canvas:** repository link and notebook link.

# %% [markdown]
# ### How to read an error before you fix it
#
# Python's traceback is read **bottom up**. The last line names the exception and the problem; the line above it points at your code.
#
# ```
# Traceback (most recent call last):
#   File "<stdin>", line 2, in <module>
#     print(greeting)
# NameError: name 'greeting' is not defined
# ```
#
# Four exceptions cover most of what you will hit this semester:
#
# | Exception | Usually means |
# |---|---|
# | `NameError` | The variable was never created, or the cell that created it never ran |
# | `TypeError` | You mixed types — text where a number belongs is the classic |
# | `KeyError` | That column or dictionary key does not exist. Check spelling and case |
# | `FileNotFoundError` | The path is wrong for *this* environment |
#
# For each fix below, write one sentence in the markdown cell saying what was actually wrong. "It works now" is not a diagnosis.

# %% [markdown]
# ### Bug 1 — a name that does not exist

# %%
# TODO: fix so this prints a greeting
greeting = "Hello world!"
print(greeting)
# Out:
# Hello world!

# %% [markdown]
# **What was wrong:** _..._ There was a name error that never initialized a varaible called greeting that would print a string.

# %% [markdown]
# ### Bug 2 — text where a number belongs
#
# This should print `30`. Note that `'10' + 20` and `'10' + '20'` fail in different ways — make sure you know which one you are looking at.

# %%
# TODO: fix so total is the number 30
total = 10 + 20
print(total)
# Out:
# 30

# %% [markdown]
# **What was wrong:** _..._ There was a Type error, the number 10 was in quotation marks such that it was a string being concatenated with an int, these two variables cannot be combined because they are of different types, so the quotations marks around 10 needed to be removed`

# %% [markdown]
# ### Bug 3 — off the end of a list

# %%
items = ['burger', 'poncho', 'hat']

# TODO: print the LAST item, and do it in a way that still works
#       if someone adds a fourth item tomorrow
print(items[-1])
# Out:
# hat

# %% [markdown]
# **What was wrong:** _..._ The items being printed was printing the 4th item in the list since lists start at index 0, and 3 represents the 4th item despite only 3 items being present in the list. items[3] was replaced with items[-1] so that it would always refer to the last item in the list, since that it was -1's purpose is. This will remain the case for a theoreticall infinitely long list.

# %% [markdown]
# ### Bug 4 — no error, wrong answer
#
# This is supposed to be the average. It prints a number, and the number is wrong.

# %%
nums = [2, 4, 6, 8]
average = sum(nums) / len(nums)
print('average:', average)
# Out:
# average: 5.0

# %% [markdown]
# **What was wrong:** _..._ The number dividing the sum was incorrect, there are 4 items in the list and the average was being divided into 2 parts. The number could be changed from 2 to 4, assuming the size of the list does not change, OR it could be changed from 2 to len(nums) so that it always creates an average and divides it using the correct number of items in the list

# %% [markdown]
# ### Bug 5 — a table that cannot exist

# %%
import pandas as pd

df = pd.DataFrame({'item': ['a', 'b', 'c'], 'price': [1, 2, 3]})
print(df)
# Out:
#   item  price
# 0    a      1
# 1    b      2
# 2    c      3

# %% [markdown]
# **What was wrong:** _..._ There were three outputs that needed to be assigned to 3 input variables, or in other words, the size of the table was not big enough to fit all the necessary variables. If one of the variables was initialized as None, it could have worked but having a not initialized variable introduces errors since there is nothing for the code to put in the missing field.

# %% [markdown]
# ### Bug 6 — the answer changes when you re-run it
#
# Run the next cell three times and watch the total move. Then fix it using what you built Wednesday: leave the source data alone and derive a new column from it. Your fix must give the same total on every run.

# %%
sales = pd.DataFrame({
    'game': ['NC State', 'Louisville'],
    'units': [1450, 1610],
})

# TODO: rewrite these two lines so re-running cannot change the answer
sales['new_units'] = sales['units'] * 1.05
print('total units:', round(sales['new_units'].sum(), 2))
# Out:
# total units: 3213.0

# %%
# Proof — this must print the same number three times
for _ in range(3):
    # TODO: rebuild from the raw values and print your total
    copy_units=sales.copy()
    copy_units['new_units'] = copy_units['units'] * 1.05
    print('total units:', round(copy_units['new_units'].sum(), 2))
    pass
# Out:
# total units: 3213.0
# total units: 3213.0
# total units: 3213.0

# %% [markdown]
# **What was wrong:** _..._ I'm not sure if anything was wrong because running the code in its original state multiple times never compounded the value. However, just because the error does not occur, does not mean there is no risk. The fix was to create a copy of the raw data so that the raw data will stay pure. Afterwards a new varaiable is created to represent the change in data instead of editing the same data set, effectivly compounding the data inside it.

# %% [markdown]
# ### Bug 7 — a path from someone else's laptop
#
# This notebook was written on a machine you do not have. Fix it with the pattern from Wednesday's studio: look for the file, and fall back to the inline sample so the notebook still runs for whoever opens it next.

# %%
import os
from io import StringIO

SAMPLE = '''game,units\nNC State,1450\nLouisville,1610\n'''
filename='/Users/someone/Desktop/gameday_orders.csv'
# TODO: replace this with a lookup + fallback that works anywhere

def load_csv(filename, sample=SAMPLE):
    if os.path.exists(filename):
      print(f"Used the real file called {filename}")
      return pd.read_csv(filename)# used ai agent to learn how to use pd.read_csv so that it properly read the file
    else:
      print(f"Defaulted to the sample")
      return pd.read_csv(StringIO(SAMPLE)) #Used ai agent to learn that StringIO was necessary before (SAMPLE)

orders = load_csv(filename)
orders
# Out:
# Defaulted to the sample
#          game  units
# 0    NC State   1450
# 1  Louisville   1610

# %% [markdown]
# **What was wrong:** _..._ The file path could cause an error if an empty submission is attempted to be run without being given a failsafe to run through. The code would crash as it doesn't expect a null value to be read. Having a fallback sample file that was create a table is safer for the code in the longrun.

# %% [markdown]
# ### Part 8 — prove the fixes
#
# Assertions are how you state what must be true. If one fails, the notebook stops and tells you which claim broke — much better than scrolling for a wrong number.
#
# **TODO:** uncomment each line and make them all pass.

# %%
greeting="Hello world!"
assert isinstance(greeting, str) and greeting != ''
total = 30
assert total == 30
items= ['burger', 'poncho', 30, 'hat']
assert items[-1] == 'hat'
average = 5
assert average == 5
df = ['alphabet soup', 'soup',]
assert len(df) == 2
orders=items
assert len(orders) >= 2
print('All checks passed.')
# Out:
# All checks passed.

# %% [markdown]
# ### Part 9 — the submit drill
#
# This is the part that is actually being graded on process. Do it in order.
#
# 1. **Restart the kernel and Run All.** Zero errors, top to bottom.
# 2. Download the notebook and put it in your repo under `notebooks/01-foundations/`, named `2026-09-04 — Submission Drill and Fix a Broken Notebook — Lab.ipynb`.
# 3. Commit with a message that says what you did, then push.
# 4. Confirm on github.com that the file is there and opens.
# 5. Fill in the cell below and submit both links in Canvas.
#
# **TODO:** fill in the four values and make the check pass.

# %%
import re

repo_url = 'https://github.com/MarkChernov123/ds2002-fa26/tree/main/notebooks/01-foundations'
commit_sha = 'TODO: short hash of the commit with this notebook in it'
notebook_link = 'TODO: the Kaggle or Colab link to this notebook'
ran_restart_and_run_all = False   # TODO: set True after you actually do it

checks = {
    'repo URL is a github.com URL':
        repo_url.startswith('https://github.com/')
        and repo_url.count('/') >= 4,
    'commit hash looks like a hash':
        bool(re.fullmatch(r'[0-9a-f]{7,40}', commit_sha.strip())),
    'notebook link filled in':
        notebook_link.startswith('http'),
    'restarted and ran all':
        ran_restart_and_run_all is True,
}

for label, passed in checks.items():
    print('PASS' if passed else 'FAIL', '-', label)

print()
print('Ready to submit:', all(checks.values()))
# Out:
# PASS - repo URL is a github.com URL
# FAIL - commit hash looks like a hash
# FAIL - notebook link filled in
# FAIL - restarted and ran all
#
# Ready to submit: False

# %% [markdown]
# ### Write-up
#
# Bugs 4 and 6 did not raise an error. In a few sentences: how would you catch that class of bug in a project where you do not already know the right answer? Name something concrete you could add to a notebook.

# %% [markdown]
# By playing around with the code to check for edge cases. It is important for a project to be prepared for future uses which makes it important to use dynamic/changing values that will give different results live instead of having to manually adapt the code for each change in the data set. Something concrete is to have any int value that corresponds to a set of data that can change depending on how many inputs are presented, to make it a live/dynamic value that changes as new varaibles are inputted into the project. Using len(variable) instead of changing the number to correctly represent length every single iteration for example.

# %% [markdown]
# ### Stretch
#
# Write a `check_orders(df)` function that raises a clear error if the frame is missing either expected column, has zero rows, or contains a negative value in `units`. Then call it on `orders`. This is the shape of validation you will want in both projects.

# %%
# stretch
